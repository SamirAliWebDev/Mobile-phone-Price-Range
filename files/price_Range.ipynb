# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns
from datasets import load_dataset

df = pd.read_csv('D:\python practice/Data Analytics/Real Dataset Practice/Mobile phone Classification/files/train.csv')

# %%
df_t = df.copy()

col_convert = ['four_g','dual_sim','talk_time','three_g','touch_screen','wifi']

#using the replace method to change number to boolean
for cols in col_convert:
    df_t[cols] = df_t[cols].replace({1:'Yes',0:'No'})

# %%
#using the corr() method to see the correlation
corelation = df.corr()['price_range'].drop('price_range')

corelation_sorted = corelation.abs().sort_values(ascending = False).reset_index()
corelation_sorted.columns = ['Feature', 'Correlation']

# %%
sns.barplot(
    data=corelation_sorted,
    x='Correlation',
    y='Feature',
    hue='Feature',           # use y variable as hue
    palette='viridis',
    legend=False             # disable duplicate legend
)
sns.despine()
plt.title("Feature Correlation with Price Range", fontsize=14)
plt.xlabel("Correlation Strength", fontsize=12)
plt.ylabel("Features", fontsize=12)
plt.tight_layout()
plt.show()
